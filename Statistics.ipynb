# %%
from scipy import stats
import pandas
import random

import matplotlib
import numpy
import matplotlib.pyplot as plt
#Данные полученные на лабе по моделированию случайной велечины 
my_series = [4.83,4.80,4.93,4.78,4.99,5.19,5.02,4.91,4.77,4.38,5.04,4.97,5.15,4.94,5.09,4.77,4.93,5.03,4.61,5.07,5.18,4.97,4.84,5.08,4.99,5.15,5.24,5.02,5.03,4.99,4.73,5.24,4.86,4.89,5.05,5.05,5.00,4.64,5.31,4.59,5.00,4.92,5.03,5.24,5.17,4.69,5.23,4.83,5.11,4.45]
df = pandas.DataFrame(data={'my_series': my_series})
df.plot.kde()
from scipy import stats

d1 = df['my_series']

print(stats.kstest(d1, 'norm', (d1.mean(), d1.std())))
print("Получается довольно неплохое соотношение К-С-статистики и Р-значения (малое значение К-С-статистики и высокое P-знчения), значит можно считать полученное распределение близким к нормальному")
# Out:
# KstestResult(statistic=0.1104207611448012, pvalue=0.5500655427770285)
# Получается довольно неплохое соотношение К-С-статистики и Р-значения (малое значение К-С-статистики и высокое P-знчения), значит можно считать полученное распределение близким к нормальному
